# %% [markdown]
# <a href="https://colab.research.google.com/github/pedromarinhoabreu44-code/projeto-final-biblioteca-digital/blob/feator-estrutura-inicial/projetofinaltcc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sistema de bibliotecas:
#
# 1.  draw.io

# %%
#projeto inicial
libra={}

cont = True
while cont:
    print("boas vindas à biblioteca leitura")
    op=int(input("qual operação voce deseja? operações: 1=adicionar livro , 2=emprestar livro, 3=devolver livro?"))
    #adiciona o livro no sistema------------------------------------------------------------------------------------------
    if op == 1:
        def add_book(titulo, quantidade, id_livro):
            livro=input("qual titulo do livro ?")
            quan=int(input("qual a quantidade? "))
            codig=int(input("qual o ID? "))
            print(f"Livro '{livro}' (ID: {codig}) com {quan} unidades adicionado.")

        add_book("", 0, 0)

    #emprestimo de livros-------------------------------------------------------------------------------------------------
    elif op == 2:
        def lend_book():
            book_to_lend = input("Qual livro deseja emprestar?")
            quantidade_disponivel = 5
            if quantidade_disponivel <= 0:
                print("Livro indisponivel ")
.            else:
                print("Emprestimo feito")
#crie uma linha que tira um deste livro do banco de dados
        lend_book()
#devolução  de livros------------------------------------------------------------------------------------------------------
    elif op == 3:
        def devlut_():

            input("titulo do livro: ")
            input("ID do livro: ")
            print("devolução feita")
#crie uma linha que volta um deste banco de dados e caso este livro for nosso rejeite
        devlut_()
#operação inválida--------------------------------------------------------------------------------------------------------
    else:
        print("Operação inválida. Por favor, escolha 1, 2 ou 3.")

    # opção para sair do loop---------------------------------------------------------------------------------------------
    continue_choice = input("Deseja realizar outra operação? (s/n): ").lower()
    if continue_choice != 's':
        cont = False
# Out:
#   File "<tokenize>", line 28
#     lend_book()
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#projeto inicial
libra={}

cont = True
while cont:
    print("boas vindas à biblioteca leitura")
    op=int(input("qual operação voce deseja? operações: 1=adicionar livro , 2=emprestar livro, 3=devolver livro?"))
    #adiciona o livro no sistema------------------------------------------------------------------------------------------
    if op == 1:
        def add_book(titulo, quantidade, id_livro):
            livro=input("qual titulo do livro ?")
            quan=int(input("qual a quantidade? "))
            codig=int(input("qual o ID? "))
            print(f"Livro '{livro}' (ID: {codig}) com {quan} unidades adicionado.")

        add_book("", 0, 0)

    #emprestimo de livros-------------------------------------------------------------------------------------------------
    elif op == 2:
        def emp_book():
            book_lend = input("Qual livro deseja emprestar?")
            quantidade_disponivel = 5
            if quantidade_disponivel <= 0:
                print("Livro indisponivel ")
            else:
                print("Emprestimo feito")

        emp_book()
#devolução  de livros------------------------------------------------------------------------------------------------------
    elif op == 3:
        def devlut_():

            input("titulo do livro: ")
            input("ID do livro: ")
            print("devolução feita")

        devolut_()
#operação inválida--------------------------------------------------------------------------------------------------------
    else:
        print("Operação inválida. Por favor, escolha 1, 2 ou 3.")

    # opção para sair do loop---------------------------------------------------------------------------------------------
    continue_ = input("Deseja realizar outra operação? (s/n): ").lower()
    if continue_ != 's':
        cont = False
# Out:
# boas vindas à biblioteca leitura
# qual operação voce deseja? operações: 1=adicionar livro , 2=emprestar livro, 3=devolver livro?1
# qual titulo do livro ?io
# qual a quantidade? 1
# qual o ID? 123
# Livro 'io' (ID: 123) com 1 unidades adicionado.
# Deseja realizar outra operação? (s/n): s
# boas vindas à biblioteca leitura
# qual operação voce deseja? operações: 1=adicionar livro , 2=emprestar livro, 3=devolver livro?2
# Qual livro deseja emprestar?ei
# Emprestimo feito
# Deseja realizar outra operação? (s/n): n
